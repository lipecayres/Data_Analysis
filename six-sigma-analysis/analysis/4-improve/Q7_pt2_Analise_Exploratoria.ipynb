# %% [markdown]
# ##**Análise descritiva e exploratória**

# %% [markdown]
# **Bibliotecas utilizadas**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importar dados pre processados**

# %%
dataset = pd.read_csv("Dados_pre_processados.csv")

# %% [markdown]
# **Gráficos**

# %%
sns.lmplot('cookie-length', 'cookie-width', data = dataset, fit_reg = False,
           hue = "status", scatter_kws = {"marker": "D", "s": 50})

plt.title('Comprimento do Biscoito vs Largura do Biscoito')
plt.xlabel("Comprimento da Sépala")
plt.ylabel("Largura da Sépala")

plt.show()
# Out:
# c:\Users\felip\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('petal-length', 'petal-width', data = dataset, fit_reg = False,
           hue = "status", scatter_kws = {"marker": "D", "s": 50})

plt.title('Comprimento da Pétala vs Largura da Pétala')
plt.xlabel("Comprimento da Pétala")
plt.ylabel("Largura da Pétala")

plt.show()
# Out:
# c:\Users\felip\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\VSCode\Data_Analysis\six-sigma-analysis\analysis\4-improve\Q7_pt2_Analise_Exploratoria.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/VSCode/Data_Analysis/six-sigma-analysis/analysis/4-improve/Q7_pt2_Analise_Exploratoria.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> sns.lmplot('petal-length', 'petal-width', data = dataset, fit_reg = False,
#       <a href='vscode-notebook-cell:/c%3A/VSCode/Data_Analysis/six-sigma-analysis/analysis/4-improve/Q7_pt2_Analise_Exploratoria.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>            hue = "status", scatter_kws = {"marker": "D", "s": 50})
#       <a href='vscode-notebook-cell:/c%3A/VSCode/Data_Analysis/six-sigma-analysis/analysis/4-improve/Q7_pt2_Analise_Exploratoria.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> plt.title('Comprimento da Pétala vs Largura da Pétala')
#       <a href='vscode-notebook-cell:/c%3A/VSCode/Data_Analysis/six-sigma-analysis/analysis/4-improve/Q7_pt2_Analise_Exploratoria.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> plt.xlabel("Comprimento da Pétala")
#
# File c:\Users\felip\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\felip\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:605, in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
#     603 need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     604 cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 605 data = data[cols]
#     607 # Initialize the grid
#     608 facets = FacetGrid(
#     609     data, row=row, col=col, hue=hue,
#     610     palette=palette,
#    (...)
#     613     **facet_kws,
#     614 )
#
# File c:\Users\felip\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\felip\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File c:\Users\felip\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5859, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['petal-length', 'petal-width'] not in index"

# %%
sns.lmplot('sepal-length', 'sepal-width', data = dataset, fit_reg = False,
           hue = "class", scatter_kws = {"marker": "D", "s": 50})

plt.title('Comprimento da Sépala vs Comprimento da Pétala')
plt.xlabel("Comprimento da Sépala")
plt.ylabel("Comprimento da Pétala")

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot('sepal-width', 'petal-width', data = dataset, fit_reg = False,
           hue = "class", scatter_kws = {"marker": "D", "s": 50})

plt.title('Largura da Sépala vs Largura da Pétala')
plt.xlabel("Largura da Sépala")
plt.ylabel("Largura da Pétala")

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
